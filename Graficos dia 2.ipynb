# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#%matplotlib ipympl
plt.style.use('./figuras.mplstyle')

# %% [markdown]
# ARCHIVO: Fotoelectrico csv

# %%
nombre = f'fotoelectrico'
df = pd.read_csv(f'./Mediciones Dia 2/{nombre}.csv')

V_ret = df['Potencial Retardador'].values
I = df['Corriente'].values
fase = df['Desfasaje'].values
escala_temp = df['EscTemporal'].values
escala_amp = df['EscAmplitud'].values

fig, ax = plt.subplots()

ax.plot(V_ret,I)
ax.set_title(f'fotoelectrico.csv')
ax.set_xlabel(r'Corriente [$\mu A$]')
ax.set_ylabel(r'Potencial externo [V]')
plt.show()

fig.savefig(rf'./Figuras/Mediciones dia 2/{nombre}.png',dpi = 800,bbox_inches="tight")

# %%
nombre = f'barrido, -1.5 a 1.0, lamda=476'
df = pd.read_csv(f'./Mediciones Dia 2/{nombre}.csv')

V_ret = df['Potencial Retardador'].values
I = df['Corriente'].values
fase = df['Desfasaje'].values
escala_temp = df['EscTemporal'].values
escala_amp = df['EscAmplitud'].values

fig, ax = plt.subplots()

ax.plot(V_ret,I)
ax.set_title(f'barrido, -1.5 a 1.0, lamda=476.csv')
ax.set_xlabel(r'Corriente [$\mu A$]')
ax.set_ylabel(r'Potencial externo [V]')
plt.show()

fig.savefig(rf'./Figuras/Mediciones dia 2/{nombre}.png',dpi = 800,bbox_inches="tight")

# %%
nombre = f'barrido, -1.5 a 1.0, lamda=456'
df = pd.read_csv(f'./Mediciones Dia 2/{nombre}.csv')

V_ret = df['Potencial Retardador'].values
I = df['Corriente'].values
fase = df['Desfasaje'].values
escala_temp = df['EscTemporal'].values
escala_amp = df['EscAmplitud'].values

fig, ax = plt.subplots()

ax.plot(V_ret,I)
ax.set_title(f'barrido, -1.5 a 1.0, lamda=456.csv')
ax.set_xlabel(r'Corriente [$\mu A$]')
ax.set_ylabel(r'Potencial externo [V]')
plt.show()

fig.savefig(rf'./Figuras/Mediciones dia 2/{nombre}.png',dpi = 800,bbox_inches="tight")

# %%
nombre = f'barrido_fotoelectrico2 -1.0 a 1.0'

df = pd.read_csv(f'./Mediciones Dia 2/{nombre}.csv')

V_ret = df['Potencial Retardador'].values
I = df['Corriente'].values
fase = df['Desfasaje'].values
escala_temp = df['EscTemporal'].values
escala_amp = df['EscAmplitud'].values

fig, ax = plt.subplots()

ax.plot(V_ret,I)
ax.set_title(f'{nombre}')
ax.set_xlabel(r'Corriente [$\mu A$]')
ax.set_ylabel(r'Potencial externo [V]')
plt.show()

fig.savefig(rf'./Figuras/Mediciones dia 2/{nombre}.png',dpi = 800,bbox_inches="tight")

# %%
nombre = f'barrido_fotoelectrico2 -1.0 a 1.0'

df = pd.read_csv(f'./Mediciones Dia 2/{nombre}.csv')

V_ret = df['Potencial Retardador'].values
I = df['Corriente'].values
fase = df['Desfasaje'].values
escala_temp = df['EscTemporal'].values
escala_amp = df['EscAmplitud'].values

fig, ax = plt.subplots()

ax.plot(V_ret,I)
ax.set_title(f'{nombre}')
ax.set_xlabel(r'Corriente [$\mu A$]')
ax.set_ylabel(r'Potencial externo [V]')
plt.show()

fig.savefig(rf'./Figuras/Mediciones dia 2/{nombre}.png',dpi = 800,bbox_inches="tight")

# %%
nombre = f'barrido_fotoelectrico_-3.0 a 3.0'

df = pd.read_csv(f'./Mediciones Dia 2/{nombre}.csv')

V_ret = df['Potencial Retardador'].values
I = df['Corriente'].values
fase = df['Desfasaje'].values
escala_temp = df['EscTemporal'].values
escala_amp = df['EscAmplitud'].values

fig, ax = plt.subplots()

ax.plot(V_ret,I)
ax.set_title(f'{nombre}')
ax.set_xlabel(r'Corriente [$\mu A$]')
ax.set_ylabel(r'Potencial externo [V]')
plt.show()

fig.savefig(rf'./Figuras/Mediciones dia 2/{nombre}.png',dpi = 800,bbox_inches="tight")

# %%
nombre = f'barrido_fotoelectrico -3.0 a 3.0'

df = pd.read_csv(f'./Mediciones Dia 2/{nombre}.csv')

V_ret = df['Potencial Retardador'].values
I = df['Corriente'].values
fase = df['Desfasaje'].values
escala_temp = df['EscTemporal'].values
escala_amp = df['EscAmplitud'].values

fig, ax = plt.subplots()

ax.plot(V_ret,I)
ax.set_title(f'{nombre}')
ax.set_xlabel(r'Corriente [$\mu A$]')
ax.set_ylabel(r'Potencial externo [V]')
plt.show()

fig.savefig(rf'./Figuras/Mediciones dia 2/{nombre}.png',dpi = 800,bbox_inches="tight")

# %%
nombre = f'barrido_escaleadoAmano, -3.0 a 9.0, lamda=470, ti = 1s'

df = pd.read_csv(f'./Mediciones Dia 2/{nombre}.csv')

V_ret = df['Potencial Retardador'].values
I = df['Corriente'].values
fase = df['Desfasaje'].values
escala_temp = df['EscTemporal'].values
escala_amp = df['EscAmplitud'].values

fig, ax = plt.subplots()

ax.plot(V_ret,I)
ax.set_title(f'{nombre}')
ax.set_xlabel(r'Corriente [$\mu A$]')
ax.set_ylabel(r'Potencial externo [V]')
plt.show()

fig.savefig(rf'./Figuras/Mediciones dia 2/{nombre}.png',dpi = 800,bbox_inches="tight")

# %%
nombre = f'barrido_escaleadoAmano, -3.0 a 1.0, lamda=496, ti = 1s'

df = pd.read_csv(f'./Mediciones Dia 2/{nombre}.csv')

V_ret = df['Potencial Retardador'].values
I = df['Corriente'].values
fase = df['Desfasaje'].values
escala_temp = df['EscTemporal'].values
escala_amp = df['EscAmplitud'].values

fig, ax = plt.subplots()

ax.plot(V_ret,I)
ax.set_title(f'{nombre}')
ax.set_xlabel(r'Corriente [$\mu A$]')
ax.set_ylabel(r'Potencial externo [V]')
plt.show()

fig.savefig(rf'./Figuras/Mediciones dia 2/{nombre}.png',dpi = 800,bbox_inches="tight")

# %%
nombre = f'barrido_escaleadoAmano, -3.0 a 1.0, lamda=476, ti = 300ms'

df = pd.read_csv(f'./Mediciones Dia 2/{nombre}.csv')

V_ret = df['Potencial Retardador'].values
I = df['Corriente'].values
fase = df['Desfasaje'].values
escala_temp = df['EscTemporal'].values
escala_amp = df['EscAmplitud'].values

fig, ax = plt.subplots()

ax.plot(V_ret,I)
ax.set_title(f'{nombre}')
ax.set_xlabel(r'Corriente [$\mu A$]')
ax.set_ylabel(r'Potencial externo [V]')
plt.show()

fig.savefig(rf'./Figuras/Mediciones dia 2/{nombre}.png',dpi = 800,bbox_inches="tight")

# %%
nombre = f'barrido_escaleadoAmano, -2.0 a 6.0, lamda=470, ti = 1s'

df = pd.read_csv(f'./Mediciones Dia 2/{nombre}.csv')

V_ret = df['Potencial Retardador'].values
I = df['Corriente'].values
fase = df['Desfasaje'].values
escala_temp = df['EscTemporal'].values
escala_amp = df['EscAmplitud'].values

fig, ax = plt.subplots()

ax.plot(V_ret,I)
ax.set_title(f'{nombre}')
ax.set_xlabel(r'Corriente [$\mu A$]')
ax.set_ylabel(r'Potencial externo [V]')
plt.show()

fig.savefig(rf'./Figuras/Mediciones dia 2/{nombre}.png',dpi = 800,bbox_inches="tight")

# %%
nombre = f'barrido_escaleadoAmano, -2.0 a 1.0, lamda=476'

df = pd.read_csv(f'./Mediciones Dia 2/{nombre}.csv')

V_ret = df['Potencial Retardador'].values
I = df['Corriente'].values
fase = df['Desfasaje'].values
escala_temp = df['EscTemporal'].values
escala_amp = df['EscAmplitud'].values

fig, ax = plt.subplots()

ax.plot(V_ret,I)
ax.set_title(f'{nombre}')
ax.set_xlabel(r'Corriente [$\mu A$]')
ax.set_ylabel(r'Potencial externo [V]')
plt.show()

fig.savefig(rf'./Figuras/Mediciones dia 2/{nombre}.png',dpi = 800,bbox_inches="tight")

# %%
nombre = f'barrido_escaleadoAmano, -1.5 a 1.0, lamda=456'

df = pd.read_csv(f'./Mediciones Dia 2/{nombre}.csv')

V_ret = df['Potencial Retardador'].values
I = df['Corriente'].values
fase = df['Desfasaje'].values
escala_temp = df['EscTemporal'].values
escala_amp = df['EscAmplitud'].values

fig, ax = plt.subplots()

ax.plot(V_ret,I)
ax.set_title(f'{nombre}')
ax.set_xlabel(r'Corriente [$\mu A$]')
ax.set_ylabel(r'Potencial externo [V]')
plt.show()

fig.savefig(rf'./Figuras/Mediciones dia 2/{nombre}.png',dpi = 800,bbox_inches="tight")
